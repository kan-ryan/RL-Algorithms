# %%
pip install gymnasium tqdm
# Out:
# Requirement already satisfied: gymnasium in /Users/ryankan/opt/anaconda3/envs/ml_algorithms/lib/python3.11/site-packages (0.28.1)
# Requirement already satisfied: tqdm in /Users/ryankan/opt/anaconda3/envs/ml_algorithms/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ryankan/opt/anaconda3/envs/ml_algorithms/lib/python3.11/site-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /Users/ryankan/opt/anaconda3/envs/ml_algorithms/lib/python3.11/site-packages (from gymnasium) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/ryankan/opt/anaconda3/envs/ml_algorithms/lib/python3.11/site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/ryankan/opt/anaconda3/envs/ml_algorithms/lib/python3.11/site-packages (from gymnasium) (4.6.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/ryankan/opt/anaconda3/envs/ml_algorithms/lib/python3.11/site-packages (from gymnasium) (0.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.distributions as distributions

import matplotlib.pyplot as plt
import numpy as np
import gymnasium as gym
import sys

# %%
# Neural Net
class NN(nn.Module):
    
    def __init__(self, n_observations, n_actions):
        super(NN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)  # Input layer
        self.layer2 = nn.Linear(128, 128)  # Hidden layer
        self.layer3 = nn.Linear(128, n_actions)  # Output layer

    def forward(self, x):
        x = F.relu(self.layer1(x))  # Activation function for the first layer
        x = F.relu(self.layer2(x))  # Activation function for the second layer
        x = F.dropout(x, p=0.5)  # Dropout regularization
        x = self.layer3(x)  # Output layer
        return x

# %%
def compute_returns(rewards, discount_factor):
    returns = []
    G = 0

    for g in reversed(rewards):
        G = g + G * discount_factor  # Discounted return calculation
        returns.insert(0, G)  # Prepend the discounted return 
    returns = torch.tensor(returns)

    return returns

# %%
def optimize(returns, log_prob_actions, optimizer):
    
    loss = - (returns * log_prob_actions).sum()  # Policy gradient loss calculation

    optimizer.zero_grad()

    loss.backward()  # Backpropagation

    optimizer.step()  # Parameter update

    return loss.item()

# %%
n_observations = train_env.observation_space.shape[0]
n_actions = train_env.action_space.n

policy_net = NN(n_observations, n_actions)
policy_net.load_state_dict(policy_net.state_dict())

optimizer = optim.Adam(policy_net.parameters(), lr=0.001)

gamma = 0.99  # Discount factor
num_episodes = 500
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
env = gym.make('CartPole-v1')
episodes = []
train_rewards = []

for episode in range(1, num_episodes+1):
    
    log_prob_actions = []
    rewards = []
    done = False
    episode_reward = 0

    state, _ = env.reset()

    for i in range(1000):
        
        state = torch.FloatTensor(state).unsqueeze(0).to(device)

        action_pred = policy_net(state)

        action_prob = F.softmax(action_pred, dim=-1)

        dist = distributions.Categorical(action_prob)  # Categorical distribution over actions

        action = dist.sample()  # Sample an action from the distribution

        log_prob_action = dist.log_prob(action)  # Log probability of the sampled action

        state, reward, terminated, truncated, _ = env.step(action.item())  # Take the action in the environment
        done = terminated or truncated
        log_prob_actions.append(log_prob_action)
        rewards.append(reward)

        episode_reward += reward
        if done:
            break

    log_prob_actions = torch.cat(log_prob_actions)

    returns = compute_returns(rewards, gamma)  # Compute the returns

    loss = optimize(returns, log_prob_actions, optimizer)  # Update the policy network

    train_reward = episode_reward

    episodes.append(episode)
    train_rewards.append(train_reward)

    print('episode: ', episode)
    print('train reward: ', train_reward)
    print()
# Out:
# episode:  1
# train reward:  17.0
#
# episode:  2
# train reward:  18.0
#
# episode:  3
# train reward:  16.0
#
# episode:  4
# train reward:  37.0
#
# episode:  5
# train reward:  14.0
#
# episode:  6
# train reward:  19.0
#
# episode:  7
# train reward:  24.0
#
# episode:  8
# train reward:  21.0
#
# episode:  9
# train reward:  15.0
#
# episode:  10
# train reward:  44.0
#
# episode:  11
# train reward:  25.0
#
# episode:  12
# train reward:  29.0
#
# episode:  13
# train reward:  18.0
#
# episode:  14
# train reward:  12.0
#
# episode:  15
# train reward:  45.0
#
# episode:  16
# train reward:  12.0
#
# episode:  17
# train reward:  11.0
#
# episode:  18
# train reward:  43.0
#
# episode:  19
# train reward:  16.0
#
# episode:  20
# train reward:  13.0
#
# episode:  21
# train reward:  9.0
#
# episode:  22
# train reward:  26.0
#
# episode:  23
# train reward:  32.0
#
# episode:  24
# train reward:  27.0
#
# episode:  25
# train reward:  17.0
#
# episode:  26
# train reward:  14.0
#
# episode:  27
# train reward:  39.0
#
# episode:  28
# train reward:  19.0
#
# episode:  29
# train reward:  17.0
#
# episode:  30
# train reward:  36.0
#
# episode:  31
# train reward:  40.0
#
# episode:  32
# train reward:  38.0
#
# episode:  33
# train reward:  31.0
#
# episode:  34
# train reward:  17.0
#
# episode:  35
# train reward:  53.0
#
# episode:  36
# train reward:  36.0
#
# episode:  37
# train reward:  21.0
#
# episode:  38
# train reward:  41.0
#
# episode:  39
# train reward:  58.0
#
# episode:  40
# train reward:  49.0
#
# episode:  41
# train reward:  33.0
#
# episode:  42
# train reward:  41.0
#
# episode:  43
# train reward:  35.0
#
# episode:  44
# train reward:  29.0
#
# episode:  45
# train reward:  14.0
#
# episode:  46
# train reward:  42.0
#
# episode:  47
# train reward:  134.0
#
# episode:  48
# train reward:  89.0
#
# episode:  49
# train reward:  54.0
#
# episode:  50
# train reward:  23.0
#
# episode:  51
# train reward:  59.0
#
# episode:  52
# train reward:  42.0
#
# episode:  53
# train reward:  51.0
#
# episode:  54
# train reward:  55.0
#
# episode:  55
# train reward:  29.0
#
# episode:  56
# train reward:  16.0
#
# episode:  57
# train reward:  35.0
#
# episode:  58
# train reward:  39.0
#
# episode:  59
# train reward:  33.0
#
# episode:  60
# train reward:  87.0
#
# episode:  61
# train reward:  18.0
#
# episode:  62
# train reward:  57.0
#
# episode:  63
# train reward:  64.0
#
# episode:  64
# train reward:  22.0
#
# episode:  65
# train reward:  66.0
#
# episode:  66
# train reward:  32.0
#
# episode:  67
# train reward:  68.0
#
# episode:  68
# train reward:  21.0
#
# episode:  69
# train reward:  69.0
#
# episode:  70
# train reward:  92.0
#
# episode:  71
# train reward:  57.0
#
# episode:  72
# train reward:  57.0
#
# episode:  73
# train reward:  70.0
#
# episode:  74
# train reward:  33.0
#
# episode:  75
# train reward:  66.0
#
# episode:  76
# train reward:  54.0
#
# episode:  77
# train reward:  118.0
#
# episode:  78
# train reward:  46.0
#
# episode:  79
# train reward:  105.0
#
# episode:  80
# train reward:  59.0
#
# episode:  81
# train reward:  100.0
#
# episode:  82
# train reward:  66.0
#
# episode:  83
# train reward:  31.0
#
# episode:  84
# train reward:  46.0
#
# episode:  85
# train reward:  78.0
#
# episode:  86
# train reward:  47.0
#
# episode:  87
# train reward:  41.0
#
# episode:  88
# train reward:  69.0
#
# episode:  89
# train reward:  43.0
#
# episode:  90
# train reward:  56.0
#
# episode:  91
# train reward:  70.0
#
# episode:  92
# train reward:  35.0
#
# episode:  93
# train reward:  116.0
#
# episode:  94
# train reward:  50.0
#
# episode:  95
# train reward:  52.0
#
# episode:  96
# train reward:  25.0
#
# episode:  97
# train reward:  55.0
#
# episode:  98
# train reward:  45.0
#
# episode:  99
# train reward:  29.0
#
# episode:  100
# train reward:  42.0
#
# episode:  101
# train reward:  97.0
#
# episode:  102
# train reward:  69.0
#
# episode:  103
# train reward:  66.0
#
# episode:  104
# train reward:  57.0
#
# episode:  105
# train reward:  70.0
#
# episode:  106
# train reward:  53.0
#
# episode:  107
# train reward:  39.0
#
# episode:  108
# train reward:  101.0
#
# episode:  109
# train reward:  77.0
#
# episode:  110
# train reward:  80.0
#
# episode:  111
# train reward:  65.0
#
# episode:  112
# train reward:  54.0
#
# episode:  113
# train reward:  59.0
#
# episode:  114
# train reward:  33.0
#
# episode:  115
# train reward:  72.0
#
# episode:  116
# train reward:  31.0
#
# episode:  117
# train reward:  97.0
#
# episode:  118
# train reward:  45.0
#
# episode:  119
# train reward:  69.0
#
# episode:  120
# train reward:  49.0
#
# episode:  121
# train reward:  40.0
#
# episode:  122
# train reward:  54.0
#
# episode:  123
# train reward:  53.0
#
# episode:  124
# train reward:  69.0
#
# episode:  125
# train reward:  49.0
#
# episode:  126
# train reward:  55.0
#
# episode:  127
# train reward:  43.0
#
# episode:  128
# train reward:  52.0
#
# episode:  129
# train reward:  67.0
#
# episode:  130
# train reward:  74.0
#
# episode:  131
# train reward:  33.0
#
# episode:  132
# train reward:  59.0
#
# episode:  133
# train reward:  63.0
#
# episode:  134
# train reward:  26.0
#
# episode:  135
# train reward:  49.0
#
# episode:  136
# train reward:  38.0
#
# episode:  137
# train reward:  79.0
#
# episode:  138
# train reward:  73.0
#
# episode:  139
# train reward:  47.0
#
# episode:  140
# train reward:  19.0
#
# episode:  141
# train reward:  68.0
#
# episode:  142
# train reward:  35.0
#
# episode:  143
# train reward:  22.0
#
# episode:  144
# train reward:  36.0
#
# episode:  145
# train reward:  58.0
#
# episode:  146
# train reward:  42.0
#
# episode:  147
# train reward:  40.0
#
# episode:  148
# train reward:  66.0
#
# episode:  149
# train reward:  32.0
#
# episode:  150
# train reward:  45.0
#
# episode:  151
# train reward:  43.0
#
# episode:  152
# train reward:  38.0
#
# episode:  153
# train reward:  59.0
#
# episode:  154
# train reward:  36.0
#
# episode:  155
# train reward:  34.0
#
# episode:  156
# train reward:  63.0
#
# episode:  157
# train reward:  41.0
#
# episode:  158
# train reward:  50.0
#
# episode:  159
# train reward:  57.0
#
# episode:  160
# train reward:  37.0
#
# episode:  161
# train reward:  31.0
#
# episode:  162
# train reward:  81.0
#
# episode:  163
# train reward:  93.0
#
# episode:  164
# train reward:  55.0
#
# episode:  165
# train reward:  43.0
#
# episode:  166
# train reward:  74.0
#
# episode:  167
# train reward:  58.0
#
# episode:  168
# train reward:  31.0
#
# episode:  169
# train reward:  112.0
#
# episode:  170
# train reward:  46.0
#
# episode:  171
# train reward:  58.0
#
# episode:  172
# train reward:  112.0
#
# episode:  173
# train reward:  35.0
#
# episode:  174
# train reward:  149.0
#
# episode:  175
# train reward:  30.0
#
# episode:  176
# train reward:  48.0
#
# episode:  177
# train reward:  124.0
#
# episode:  178
# train reward:  45.0
#
# episode:  179
# train reward:  85.0
#
# episode:  180
# train reward:  71.0
#
# episode:  181
# train reward:  106.0
#
# episode:  182
# train reward:  135.0
#
# episode:  183
# train reward:  151.0
#
# episode:  184
# train reward:  99.0
#
# episode:  185
# train reward:  153.0
#
# episode:  186
# train reward:  51.0
#
# episode:  187
# train reward:  144.0
#
# episode:  188
# train reward:  113.0
#
# episode:  189
# train reward:  49.0
#
# episode:  190
# train reward:  101.0
#
# episode:  191
# train reward:  37.0
#
# episode:  192
# train reward:  121.0
#
# episode:  193
# train reward:  143.0
#
# episode:  194
# train reward:  62.0
#
# episode:  195
# train reward:  75.0
#
# episode:  196
# train reward:  60.0
#
# episode:  197
# train reward:  49.0
#
# episode:  198
# train reward:  108.0
#
# episode:  199
# train reward:  126.0
#
# episode:  200
# train reward:  96.0
#
# episode:  201
# train reward:  88.0
#
# episode:  202
# train reward:  82.0
#
# episode:  203
# train reward:  141.0
#
# episode:  204
# train reward:  133.0
#
# episode:  205
# train reward:  95.0
#
# episode:  206
# train reward:  237.0
#
# episode:  207
# train reward:  146.0
#
# episode:  208
# train reward:  94.0
#
# episode:  209
# train reward:  154.0
#
# episode:  210
# train reward:  253.0
#
# episode:  211
# train reward:  118.0
#
# episode:  212
# train reward:  65.0
#
# episode:  213
# train reward:  239.0
#
# episode:  214
# train reward:  65.0
#
# episode:  215
# train reward:  113.0
#
# episode:  216
# train reward:  49.0
#
# episode:  217
# train reward:  107.0
#
# episode:  218
# train reward:  91.0
#
# episode:  219
# train reward:  95.0
#
# episode:  220
# train reward:  75.0
#
# episode:  221
# train reward:  80.0
#
# episode:  222
# train reward:  134.0
#
# episode:  223
# train reward:  172.0
#
# episode:  224
# train reward:  145.0
#
# episode:  225
# train reward:  244.0
#
# episode:  226
# train reward:  89.0
#
# episode:  227
# train reward:  234.0
#
# episode:  228
# train reward:  203.0
#
# episode:  229
# train reward:  273.0
#
# episode:  230
# train reward:  110.0
#
# episode:  231
# train reward:  148.0
#
# episode:  232
# train reward:  101.0
#
# episode:  233
# train reward:  115.0
#
# episode:  234
# train reward:  45.0
#
# episode:  235
# train reward:  36.0
#
# episode:  236
# train reward:  67.0
# episode:  237
# train reward:  103.0
#
# episode:  238
# train reward:  118.0
#
# episode:  239
# train reward:  54.0
#
# episode:  240
# train reward:  164.0
#
# episode:  241
# train reward:  59.0
#
# episode:  242
# train reward:  115.0
#
# episode:  243
# train reward:  22.0
#
# episode:  244
# train reward:  117.0
#
# episode:  245
# train reward:  43.0
#
# episode:  246
# train reward:  94.0
#
# episode:  247
# train reward:  112.0
#
# episode:  248
# train reward:  84.0
#
# episode:  249
# train reward:  51.0
#
# episode:  250
# train reward:  112.0
#
# episode:  251
# train reward:  95.0
#
# episode:  252
# train reward:  89.0
#
# episode:  253
# train reward:  102.0
#
# episode:  254
# train reward:  78.0
#
# episode:  255
# train reward:  178.0
#
# episode:  256
# train reward:  77.0
#
# episode:  257
# train reward:  158.0
#
# episode:  258
# train reward:  144.0
#
# episode:  259
# train reward:  146.0
#
# episode:  260
# train reward:  139.0
#
# episode:  261
# train reward:  166.0
#
# episode:  262
# train reward:  152.0
#
# episode:  263
# train reward:  146.0
#
# episode:  264
# train reward:  104.0
#
# episode:  265
# train reward:  65.0
#
# episode:  266
# train reward:  66.0
#
# episode:  267
# train reward:  38.0
#
# episode:  268
# train reward:  201.0
#
# episode:  269
# train reward:  99.0
#
# episode:  270
# train reward:  192.0
#
# episode:  271
# train reward:  247.0
#
# episode:  272
# train reward:  205.0
#
# episode:  273
# train reward:  240.0
#
# episode:  274
# train reward:  232.0
#
# episode:  275
# train reward:  79.0
#
# episode:  276
# train reward:  160.0
#
# episode:  277
# train reward:  128.0
#
# episode:  278
# train reward:  155.0
#
# episode:  279
# train reward:  268.0
#
# episode:  280
# train reward:  131.0
#
# episode:  281
# train reward:  203.0
#
# episode:  282
# train reward:  84.0
#
# episode:  283
# train reward:  167.0
#
# episode:  284
# train reward:  104.0
#
# episode:  285
# train reward:  129.0
#
# episode:  286
# train reward:  260.0
#
# episode:  287
# train reward:  174.0
#
# episode:  288
# train reward:  242.0
#
# episode:  289
# train reward:  245.0
#
# episode:  290
# train reward:  158.0
#
# episode:  291
# train reward:  176.0
#
# episode:  292
# train reward:  141.0
#
# episode:  293
# train reward:  258.0
#
# episode:  294
# train reward:  252.0
#
# episode:  295
# train reward:  351.0
#
# episode:  296
# train reward:  199.0
#
# episode:  297
# train reward:  25.0
#
# episode:  298
# train reward:  120.0
#
# episode:  299
# train reward:  254.0
#
# episode:  300
# train reward:  179.0
#
# episode:  301
# train reward:  125.0
#
# episode:  302
# train reward:  193.0
#
# episode:  303
# train reward:  130.0
#
# episode:  304
# train reward:  170.0
#
# episode:  305
# train reward:  118.0
#
# episode:  306
# train reward:  31.0
#
# episode:  307
# train reward:  55.0
#
# episode:  308
# train reward:  56.0
#
# episode:  309
# train reward:  119.0
#
# episode:  310
# train reward:  44.0
#
# episode:  311
# train reward:  109.0
#
# episode:  312
# train reward:  43.0
#
# episode:  313
# train reward:  33.0
#
# episode:  314
# train reward:  105.0
#
# episode:  315
# train reward:  102.0
#
# episode:  316
# train reward:  112.0
#
# episode:  317
# train reward:  32.0
#
# episode:  318
# train reward:  33.0
#
# episode:  319
# train reward:  32.0
#
# episode:  320
# train reward:  111.0
#
# episode:  321
# train reward:  118.0
#
# episode:  322
# train reward:  108.0
#
# episode:  323
# train reward:  43.0
#
# episode:  324
# train reward:  34.0
#
# episode:  325
# train reward:  131.0
#
# episode:  326
# train reward:  30.0
#
# episode:  327
# train reward:  114.0
#
# episode:  328
# train reward:  35.0
#
# episode:  329
# train reward:  50.0
#
# episode:  330
# train reward:  42.0
#
# episode:  331
# train reward:  104.0
#
# episode:  332
# train reward:  143.0
#
# episode:  333
# train reward:  170.0
#
# episode:  334
# train reward:  109.0
#
# episode:  335
# train reward:  156.0
#
# episode:  336
# train reward:  121.0
#
# episode:  337
# train reward:  125.0
#
# episode:  338
# train reward:  124.0
#
# episode:  339
# train reward:  204.0
#
# episode:  340
# train reward:  113.0
#
# episode:  341
# train reward:  212.0
#
# episode:  342
# train reward:  285.0
#
# episode:  343
# train reward:  274.0
#
# episode:  344
# train reward:  360.0
#
# episode:  345
# train reward:  223.0
#
# episode:  346
# train reward:  268.0
#
# episode:  347
# train reward:  235.0
#
# episode:  348
# train reward:  165.0
#
# episode:  349
# train reward:  303.0
#
# episode:  350
# train reward:  441.0
#
# episode:  351
# train reward:  250.0
#
# episode:  352
# train reward:  297.0
#
# episode:  353
# train reward:  147.0
#
# episode:  354
# train reward:  500.0
#
# episode:  355
# train reward:  340.0
#
# episode:  356
# train reward:  153.0
#
# episode:  357
# train reward:  291.0
#
# episode:  358
# train reward:  186.0
#
# episode:  359
# train reward:  91.0
#
# episode:  360
# train reward:  83.0
#
# episode:  361
# train reward:  312.0
#
# episode:  362
# train reward:  249.0
#
# episode:  363
# train reward:  104.0
#
# episode:  364
# train reward:  160.0
#
# episode:  365
# train reward:  428.0
#
# episode:  366
# train reward:  110.0
#
# episode:  367
# train reward:  241.0
#
# episode:  368
# train reward:  106.0
#
# episode:  369
# train reward:  207.0
#
# episode:  370
# train reward:  112.0
#
# episode:  371
# train reward:  185.0
#
# episode:  372
# train reward:  142.0
#
# episode:  373
# train reward:  49.0
#
# episode:  374
# train reward:  113.0
#
# episode:  375
# train reward:  111.0
#
# episode:  376
# train reward:  106.0
#
# episode:  377
# train reward:  14.0
#
# episode:  378
# train reward:  20.0
#
# episode:  379
# train reward:  107.0
#
# episode:  380
# train reward:  116.0
#
# episode:  381
# train reward:  108.0
#
# episode:  382
# train reward:  23.0
#
# episode:  383
# train reward:  45.0
#
# episode:  384
# train reward:  38.0
#
# episode:  385
# train reward:  51.0
#
# episode:  386
# train reward:  106.0
#
# episode:  387
# train reward:  127.0
#
# episode:  388
# train reward:  45.0
#
# episode:  389
# train reward:  118.0
#
# episode:  390
# train reward:  120.0
#
# episode:  391
# train reward:  126.0
#
# episode:  392
# train reward:  123.0
#
# episode:  393
# train reward:  135.0
#
# episode:  394
# train reward:  126.0
#
# episode:  395
# train reward:  111.0
#
# episode:  396
# train reward:  134.0
#
# episode:  397
# train reward:  190.0
#
# episode:  398
# train reward:  128.0
#
# episode:  399
# train reward:  146.0
#
# episode:  400
# train reward:  131.0
#
# episode:  401
# train reward:  129.0
#
# episode:  402
# train reward:  158.0
#
# episode:  403
# train reward:  180.0
#
# episode:  404
# train reward:  156.0
#
# episode:  405
# train reward:  160.0
#
# episode:  406
# train reward:  193.0
#
# episode:  407
# train reward:  156.0
#
# episode:  408
# train reward:  215.0
#
# episode:  409
# train reward:  228.0
#
# episode:  410
# train reward:  219.0
#
# episode:  411
# train reward:  222.0
#
# episode:  412
# train reward:  221.0
#
# episode:  413
# train reward:  255.0
#
# episode:  414
# train reward:  257.0
#
# episode:  415
# train reward:  220.0
#
# episode:  416
# train reward:  284.0
#
# episode:  417
# train reward:  337.0
#
# episode:  418
# train reward:  336.0
#
# episode:  419
# train reward:  463.0
#
# episode:  420
# train reward:  306.0
#
# episode:  421
# train reward:  403.0
#
# episode:  422
# train reward:  438.0
#
# episode:  423
# train reward:  386.0
#
# episode:  424
# train reward:  481.0
#
# episode:  425
# train reward:  500.0
#
# episode:  426
# train reward:  500.0
#
# episode:  427
# train reward:  482.0
#
# episode:  428
# train reward:  164.0
#
# episode:  429
# train reward:  494.0
#
# episode:  430
# train reward:  500.0
#
# episode:  431
# train reward:  500.0
#
# episode:  432
# train reward:  500.0
#
# episode:  433
# train reward:  500.0
#
# episode:  434
# train reward:  500.0
#
# episode:  435
# train reward:  500.0
#
# episode:  436
# train reward:  500.0
#
# episode:  437
# train reward:  500.0
#
# episode:  438
# train reward:  500.0
#
# episode:  439
# train reward:  500.0
#
# episode:  440
# train reward:  500.0
#
# episode:  441
# train reward:  500.0
#
# episode:  442
# train reward:  500.0
#
# episode:  443
# train reward:  500.0
#
# episode:  444
# train reward:  500.0
#
# episode:  445
# train reward:  500.0
#
# episode:  446
# train reward:  500.0
#
# episode:  447
# train reward:  500.0
#
# episode:  448
# train reward:  437.0
#
# episode:  449
# train reward:  500.0
#
# episode:  450
# train reward:  213.0
#
# episode:  451
# train reward:  484.0
#
# episode:  452
# train reward:  500.0
#
# episode:  453
# train reward:  368.0
#
# episode:  454
# train reward:  498.0
#
# episode:  455
# train reward:  500.0
#
# episode:  456
# train reward:  198.0
#
# episode:  457
# train reward:  500.0
#
# episode:  458
# train reward:  500.0
#
# episode:  459
# train reward:  500.0
#
# episode:  460
# train reward:  500.0
#
# episode:  461
# train reward:  500.0
#
# episode:  462
# train reward:  500.0
#
# episode:  463
# train reward:  500.0
#
# episode:  464
# train reward:  462.0
#
# episode:  465
# train reward:  339.0
# episode:  466
# train reward:  500.0
#
# episode:  467
# train reward:  500.0
#
# episode:  468
# train reward:  410.0
#
# episode:  469
# train reward:  500.0
#
# episode:  470
# train reward:  500.0
#
# episode:  471
# train reward:  500.0
#
# episode:  472
# train reward:  500.0
#
# episode:  473
# train reward:  500.0
#
# episode:  474
# train reward:  500.0
#
# episode:  475
# train reward:  461.0
#
# episode:  476
# train reward:  493.0
#
# episode:  477
# train reward:  352.0
#
# episode:  478
# train reward:  367.0
#
# episode:  479
# train reward:  395.0
#
# episode:  480
# train reward:  375.0
#
# episode:  481
# train reward:  303.0
#
# episode:  482
# train reward:  346.0
#
# episode:  483
# train reward:  295.0
#
# episode:  484
# train reward:  500.0
#
# episode:  485
# train reward:  454.0
#
# episode:  486
# train reward:  500.0
#
# episode:  487
# train reward:  500.0
#
# episode:  488
# train reward:  500.0
#
# episode:  489
# train reward:  500.0
#
# episode:  490
# train reward:  500.0
#
# episode:  491
# train reward:  243.0
#
# episode:  492
# train reward:  358.0
#
# episode:  493
# train reward:  500.0
#
# episode:  494
# train reward:  500.0
#
# episode:  495
# train reward:  500.0
#
# episode:  496
# train reward:  432.0
#
# episode:  497
# train reward:  500.0
#
# episode:  498
# train reward:  349.0
#
# episode:  499
# train reward:  500.0
#
# episode:  500
# train reward:  500.0

# %%
plt.plot(train_rewards, label='Rewards')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Score vs Episode')
plt.grid()
plt.show()
